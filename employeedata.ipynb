# %% [markdown]
# <a href="https://colab.research.google.com/github/urs-truly-siva/urs-truly-siva/blob/main/employeedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
data={'Employee_id':np.arange(1,101),
      'Age':np.random.randint(20,65,size=100),
      'Salary':np.random.randint(14000,120000,size=100),
      'Experience':np.random.randint(1,20,size=100),
      'Performance_score':np.random.randint(1,10,size=100)
}

# %%
d1=pd.DataFrame(data)

# %%
d1.to_csv("employee_data.csv",index=False)

# %%
print("The employee dataset is:\n",d1)
# Out:
# The employee dataset is:
#      Employee_id  Age  Salary  Experience  Performance_score
# 0             1   46  118018           9                  6
# 1             2   49   70046          19                  2
# 2             3   45   30103           5                  4
# 3             4   39   48381           3                  2
# 4             5   54   78904           7                  7
# ..          ...  ...     ...         ...                ...
# 95           96   39   90900          13                  1
# 96           97   57  103116           1                  3
# 97           98   61   48201          15                  6
# 98           99   45   63598           3                  7
# 99          100   35   58456           9                  3
#
# [100 rows x 5 columns]
