# %% [markdown]
# <a href="https://colab.research.google.com/github/urs-truly-siva/urs-truly-siva/blob/main/studentdata_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the required**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **creating a dataframe**

# %%
data={'rollno':np.arange(1,61),
      'age':np.random.randint(15,21,size=60),
      'grade':np.random.randint(5,11,size=60)}

# %%
d1=pd.DataFrame(data) # used to covert data into the table format

# %%
d1.to_csv('student_data.csv',index=False)

# %%
print("The student dataset is :\n",d1)
# Out:
# The student dataset is :
#      rollno  age  grade
# 0        1   20      5
# 1        2   18      7
# 2        3   16      7
# 3        4   15      5
# 4        5   18      7
# 5        6   17      6
# 6        7   17      5
# 7        8   20      5
# 8        9   15      5
# 9       10   17      6
# 10      11   18      9
# 11      12   20      9
# 12      13   20      7
# 13      14   15      5
# 14      15   19      6
# 15      16   17      5
# 16      17   16      6
# 17      18   20      9
# 18      19   16     10
# 19      20   18      6
# 20      21   16      8
# 21      22   20      5
# 22      23   19      8
# 23      24   20      7
# 24      25   18      6
# 25      26   15      5
# 26      27   16      5
# 27      28   19      8
# 28      29   15      6
# 29      30   16      5
# 30      31   16      5
# 31      32   17     10
# 32      33   15      5
# 33      34   15      8
# 34      35   17      6
# 35      36   16     10
# 36      37   20      8
# ...

# %%
d1
# Out:
#     rollno  age  grade
# 0        1   20      5
# 1        2   18      7
# 2        3   16      7
# 3        4   15      5
# 4        5   18      7
# 5        6   17      6
# 6        7   17      5
# 7        8   20      5
# 8        9   15      5
# 9       10   17      6
# 10      11   18      9
# 11      12   20      9
# 12      13   20      7
# 13      14   15      5
# 14      15   19      6
# 15      16   17      5
# 16      17   16      6
# 17      18   20      9
# 18      19   16     10
# 19      20   18      6
# 20      21   16      8
# 21      22   20      5
# 22      23   19      8
# 23      24   20      7
# 24      25   18      6
# 25      26   15      5
# 26      27   16      5
# 27      28   19      8
# 28      29   15      6
# 29      30   16      5
# 30      31   16      5
# 31      32   17     10
# 32      33   15      5
# 33      34   15      8
# 34      35   17      6
# 35      36   16     10
# 36      37   20      8
# 37      38   15      5
# 38      39   20      8
# ...
